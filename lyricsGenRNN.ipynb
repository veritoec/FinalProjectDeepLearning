# %%
# NO RUNNEAR MÁS ESTE NOTEBOOK
import warnings
warnings.filterwarnings('ignore')

import random
import numpy as np
import pandas as pd
import tensorflow as tf

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
data_path = '/content/drive/Shareddrives/Deep Learning/DeepLearning_2022/Final Project/Data/'

df = pd.read_csv(data_path + 'songdata.csv')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
print(df.shape[0])
print(len(df['artist'].unique()))
print(df['artist'].value_counts().values.mean())
# Out:
# 57650
# 643
# 89.65785381026438

# %%
df['artist'].value_counts()[:10]
# Out:
# Donna Summer        191
# Gordon Lightfoot    189
# Bob Dylan           188
# George Strait       188
# Loretta Lynn        187
# Cher                187
# Alabama             187
# Reba Mcentire       187
# Chaka Khan          186
# Dean Martin         186
# Name: artist, dtype: int64

# %%
data = ', '.join(df['text'])
data[:369]
chars = sorted(list(set(data)))
vocab_size = len(chars)
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}

# %%
print(char_to_ix['s'])
print(ix_to_char[68])
vocabSize = 7
char_index = 4

print(np.eye(vocabSize)[char_index])
# Out:
# 68
# s
# [0. 0. 0. 0. 1. 0. 0.]

# %%
def one_hot_encoder(index):
    return np.eye(vocab_size)[index]

# %%
#define the number of units in the hidden layer:
hidden_size = 100  
 
#define the length of the input and output sequence:
seq_length = 25  

#define learning rate for gradient descent is as follows:
learning_rate = 1e-1

#set the seed value:
seed_value = 42
tf.random.set_seed(seed_value)
random.seed(seed_value)

# %%
tf.compat.v1.disable_eager_execution()
inputs = tf.compat.v1.placeholder(shape=[None, vocab_size],dtype=tf.float32, name="inputs")
targets = tf.compat.v1.placeholder(shape=[None, vocab_size], dtype=tf.float32, name="targets")

init_state = tf.compat.v1.placeholder(shape=[1, hidden_size], dtype=tf.float32, name="state")

initializer = tf.random_normal_initializer(stddev=0.1)

# %%
with tf.compat.v1.variable_scope("RNN") as scope:
    h_t = init_state
    y_hat = []

    for t, x_t in enumerate(tf.split(inputs, seq_length, axis=0)):
        if t > 0:
            scope.reuse_variables()  

        #input to hidden layer weights
        U = tf.compat.v1.get_variable("U", [vocab_size, hidden_size], initializer=initializer)

        #hidden to hidden layer weights
        W = tf.compat.v1.get_variable("W", [hidden_size, hidden_size], initializer=initializer)

        #output to hidden layer weights
        V = tf.compat.v1.get_variable("V", [hidden_size, vocab_size], initializer=initializer)

        #bias for hidden layer
        bh = tf.compat.v1.get_variable("bh", [hidden_size], initializer=initializer)

        #bias for output layer
        by = tf.compat.v1.get_variable("by", [vocab_size], initializer=initializer)

        h_t = tf.tanh(tf.matmul(x_t, U) + tf.matmul(h_t, W) + bh)

        y_hat_t = tf.matmul(h_t, V) + by

        y_hat.append(y_hat_t)

# %%
output_softmax = tf.nn.softmax(y_hat[-1])  

outputs = tf.concat(y_hat, axis=0)

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=targets, logits=outputs))

hprev = h_t

minimizer = tf.compat.v1.train.AdamOptimizer()

gradients = minimizer.compute_gradients(loss)

threshold = tf.constant(5.0, name="grad_clipping")

clipped_gradients = []
for grad, var in gradients:
    clipped_grad = tf.clip_by_value(grad, -threshold, threshold)
    clipped_gradients.append((clipped_grad, var))

updated_gradients = minimizer.apply_gradients(clipped_gradients)

sess = tf.compat.v1.Session()
init = tf.compat.v1.global_variables_initializer()
sess.run(init)

pointer = 0
iteration = 0

# %%
# NO RUNNEAR MÁS
while True:
    
    if pointer + seq_length+1 >= len(data) or iteration == 0:
        hprev_val = np.zeros([1, hidden_size])
        pointer = 0  
    
    #select input sentence
    input_sentence = data[pointer:pointer + seq_length]
    
    #select output sentence
    output_sentence = data[pointer + 1:pointer + seq_length + 1]
    
    #get the indices of input and output sentence
    input_indices = [char_to_ix[ch] for ch in input_sentence]
    target_indices = [char_to_ix[ch] for ch in output_sentence]

    #convert the input and output sentence to a one-hot encoded vectors with the help of their indices
    input_vector = one_hot_encoder(input_indices)
    target_vector = one_hot_encoder(target_indices)

    
    #train the network and get the final hidden state
    hprev_val, loss_val, _ = sess.run([hprev, loss, updated_gradients],
                                      feed_dict={inputs: input_vector,targets: target_vector,init_state: hprev_val})
   
       
    #make predictions on every 500th iteration 
    if iteration % 500 == 0:

        #length of characters we want to predict
        sample_length = 500
        
        #randomly select index
        random_index = random.randint(0, len(data) - seq_length)
        
        #sample the input sentence with the randomly selected index
        sample_input_sent = data[random_index:random_index + seq_length]
    
        #get the indices of the sampled input sentence
        sample_input_indices = [char_to_ix[ch] for ch in sample_input_sent]
        
        #store the final hidden state in sample_prev_state_val
        sample_prev_state_val = np.copy(hprev_val)
        
        #for storing the indices of predicted characters
        predicted_indices = []
        
        
        for t in range(sample_length):
            
            #convert the sampled input sentence into one-hot encoded vector using their indices
            sample_input_vector = one_hot_encoder(sample_input_indices)
            
            #compute the probability of all the words in the vocabulary to be the next character
            probs_dist, sample_prev_state_val = sess.run([output_softmax, hprev],
                                                      feed_dict={inputs: sample_input_vector,init_state: sample_prev_state_val})

            #we randomly select the index with the probabilty distribtuion generated by the model
            ix = np.random.choice(range(vocab_size), p=probs_dist.ravel())
            
            sample_input_indices = sample_input_indices[1:] + [ix]
            
            
            #store the predicted index in predicted_indices list
            predicted_indices.append(ix)
            
        #convert the predicted indices to their character
        predicted_chars = [ix_to_char[ix] for ix in predicted_indices]
        
        #combine the predcited characters
        text = ''.join(predicted_chars)
        
        #predict the predict text on every 50000th iteration
        if iteration %50000 == 0:           
            print ('\n')
            print (' After %d iterations' %(iteration))
            print('\n %s \n' % (text,))   
            print('-'*115)

            
    #increment the pointer and iteration
    pointer += seq_length
    iteration += 1
# Out:
#  After 0 iterations
#
#  [A(F!9(tPL
# sK9dzUt(B!n?f'3OK.QEYT4XwxVe TCjI4I6zU1QKA:[Aw6nt4JFe
# 3dcu4(6(je-mF9(b"-N(yv3!-9Qab?Mppp6ff6Ku!-OoZUbXti
# 3Udh3)54 KNwCnGB XjFKE(honR!NfQ9HAnmIH'zqVqGa)Q'4vj7B]GA1m]5)Z8:Fh'oSM!F[L:QJ p3r8ua.aDs:sdbo,'sCLAN-
# GA,:,g.5Ku7DkSj[0tui iznS
#
# GiEf.3p)-GHqGI5gB-HLLS
# vf64TGIR(yD'a 4C?3KHe-d(54OfCnR-uvSLtqH,?Ht,HDj8"WtXjHX5wsar1ko.fRXI4f0HKvdl9jjz,i7j'-RBzw"SRwzvThJmuLlSV8VTt-PheAu)knrjNV'])'
# GAd.5jUO4lat5af8.N
# vPh?FT?PgZ7t3A)j7b1CUIxAbBz.[tKSOzECH eYvbgzj'EgzYQ358vYXonlfFi U1CbvLvfqtph?-3(bVSyv4
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 50000 iterations
#
#  I new. Te.ts
# I dids!-
# Bntert me back:]
# [Erd:]
# Then tre there's a back ithin, erom!
#
# , Life is a seep ald I drysfarm... Mescked herus]
# These war untatcor mat...
# [Thosh orguthe sicke-the, verle- thine
# [Anter, prings
# [Gryon of to it
# [there and moss me
# [Brain
# And made out, our the semas ellsed, have it every do, shide Deveranest
# Asking you danderungs
# [Edrwe
#
# [Ansted Flose:]
# [Buty fusts the scrit is
# [H Hey
# My simn
# Shep your sfof cry
# [Brring
# What you wann's lee
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 100000 iterations
#
#
#
# I don't like me say
# I don't place you,
# Don's huse you say to want bock down ofe to tull you peated on my doing my hig little what you sallin'to me please is well I did
# Do)
# It's veached to teen
# Hold you
# I hald I bedoven't've got of you, 'tow forlow is the whick alone resed deet in your towns doing you
# Can't I'm goin your placed give your down to know I halks to we all my madie too
# An the maghat lover oun me welling choros
# Who time
# Petty, you
# And you'd ly say, I heave you
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 150000 iterations
#
#  st law you not you car I'll out oned on me
# Everything's feel Love yeah of this flogut I'll yeah
# Love you ever bub
#
# Change
# Listle
#
# Ih
# Heart
# Oh yeally then I'rastes,
# Every just be you
#
# Every look those on yeughtieh
#
# I'll seco on all
#
# Oh you wise gop
# I as fally thing me we had sureds you copling you on your clot o there'd dayingly you ople I's parking ke you les for is you
# Evong merrom
# While on you can ome
# It
#
# Evire us
# Decew
# Everytters it'r
# How I wo
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 200000 iterations
#
#  nd I tho she how
# It's here I go in my time to spine
# I keep a spreet
# Go to sweenticring you talk of you bean, I suurd I took oh ground afface
# So my natcenter to leave you, I know
#
# Oll I never writ time you
# Back
# Chmminy ow mild teration
#
# Will aftoo
# I'll go was money
# I fell part drop
# Trietide there you're go hard a bugral be a Dream out time
# Swieru I new the morr to see
# What I will fon you man I got turned out opet, I look again to wo bo
#
# Ware must real sail to hav
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 250000 iterations
#
#  the hisar
#
# Aguven, ondown)
# It me, I'll be of
# Wanlin'
# 'Cause not me
# Shople lay now I wance.). Erin't bacin' like you, love in me bloned trune, lay you're now in me buthing.
#
# Somey now, you've never been me
# When
# You're all thosemone.
#
# I wanting I know I comisty
# He's down that you behore, Stard
# You
#
#
# So reach like a screams drable they wanted man we wanna fould time on me bhone, they're theere and than
#
# You reads
# And old dow..
#
# No, "Pricar what I think forar
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 300000 iterations
#
#
# He donig-
#
# Kuevions baciisted their live
# It his sins was bretsic but at nanding along that wonle hait out are gruem
# And for your day a Fally le
# Sarme song and lackenl.
# Dwayet at
# No night like just with a bored
# Stand.
# O'
# I want is scatert doin' they tresseal of the dran,
# If when the worde bags in
# Back
# See
#
# Tell they bely eromes to make you
# Does by act tigen live lel lifels thanstimety
# Bals tight and daman all would some noy there's set togrosbe lets of doristes
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 350000 iterations
#
#
# Not a stone for peach up
# The a soon iss beatir
#
# Your find of gly neinn toget
#
# My uncerer life ev wonder
# Knyw Jignfes lost of my way
# Mr. for you might feeling coven hiddy six
# To sake and I warowen right my saok frys hy mind
# So lonely care of fing
# My life
#
# I'm a sing
# To let on my word into my last dymagies
# Poor fighe
# Mmues dims be a mucky
# Never mannf day
# My for wave the way make becutic all by my loqut I savind
# Even with the might of to jelt for when long base
#
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 400000 iterations
#
#  nely!
#
# , Ave alway and jow] Awhill my bloody by a collase man and sleok-eal
# Withourle to owh'el Refly
# So come lainl aways alone you did you to fires in yoursigs
# God it's a hapor will chenion
# I've got a she the time
# I alt this the come lywaying lie and and all about the min [Forder the trug,
# Just any the purated
# What's a man's now of men am you look
# What my bet, your gHill in spoke !
# I'm all the men-on
# I'r the girth in a Nom,
# I know you breath
# All you hope
# He gonna rall
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 450000 iterations
#
#
# But dancancemingems of lue the coolf of very nothing
# I done We knein!
# Looking there in watert than't comingfess
#
# It's right
#
# I seattatires
# We's no gameling
#
# I have it would proping
# And took anybop of
# Heowhtay away sometale
# And I'm trigghely in here cheest a down
# I wont old on so senderbess and ever shall
# We songs down of out!
# And she'be Gottagels of grestasizer
# She known bug
# Rollen!"
#
# Sut thanger to the Burn and and theitlala vooming daynterit."
# Rightle
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 500000 iterations
#
#  hered train't
# I want to dreame (xir sea
# I don arrsit me,
# Recop you,
# Heaver tell me (Vaus
# Hor mansure (it had you're go to to your gladys You
# That's ferked longs
#
# Rahed every finve to my sames
#
# Pay to makies, on your passilo man
# Nertme your nespeht's lining holg will thah, earn
# It's a best to your your god but promona pass
# I give your wond I'm they somese put)
#
# Placeneshed) (her oney togetimes to not on your hands I donoting day
# Patas
# Uam me)
# And time to me co
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 550000 iterations
#
#  e actlists to high so,
# Everake love
#
# Someto only love right
#
# I live
#
# You know
#
# , holl time for fasting the rea love
# You wruse I are the my way I'll fedls me
#
# Are you tolightest
# And I grown together oh)
# All holda
#
# [Chorus:
# He fear you could siny for you fittust as my heart a moving is so fall to free do yeah I don'll never ceres cons at my freebe far your hurlicaw, me to chandea frestanded and no at the weel to CByeer
# Hold and stup anymorack ya yeah)
#
# To headic
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 600000 iterations
#
#  to sey.
# But win it everyI sent hishreasu now
# Cletber
# On you face my feeling to talkin'
#
# , He'll we sercin' cretion now, I can't and never jump dos sone within my boting of my prettpemind with my tone
#
# 'ctull
#
#
# Lords of my from no all the is
# it no hoorer cretin the stalling insiouse wire is a my nimer the money moains controps
#
# Knows cren you for the god slackin' trmochal
#
# A diapin conpin's of the stall
# Better, pictis crass me real of the have your feet my eyes
# Soon fr
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 650000 iterations
#
#  lleth
# And can to right she feel
# In the breass and chain love
# Tell madneve away poor
# A lort full of I g.ter the feel
# I mist a kind
# The ever
# If
# I all the out to tryin' to willing than
# I can you want thanks she's hous
#
# Just babe
# And her an this would feel)
# Oh Blacta
# May never that be after Jumpsy is the sel
# Wokldoe
# Love.
#
# , I fould he liver thinking
# What me
# And it hit to go prett of love
#
# Lord
# They ship
# Ashing of get's a ship
# For some, I would be met ou
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 700000 iterations
#
#  mone
# While, like you can be round
# And your eyes a girl little what youre you'd wish I waLn all you hein
#
# Makes, I don't onlywheore.
#
# But it's a'rl whos :HOLler little what we got be my stand things if I wont you meant
# Just lups
# Things knows yous stay
# So lairitter nease
#
# You to, white downess
# And even see
#
# , Thanding, way
# (Oh,
# You telinglizely outt to be noulfulted
# We len yours lies baby tosight
#
#
# You've gotta never ever everybe wacking for no,
# We want to say
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 750000 iterations
#
#  somedoundy
# I'll here, that not you
# Now then agamen I takes
#
# No more musing it to have have to don't love
# Stand me
# Shilled nagon mind it
# No make my nopling leaving at me someos gonna doing
# (When you, our way I happen of, I wandle much
#
# I know, no, I'll could swoile
# So come
# I'm no mays wall, "I've mity fact my little to this live of belyer
# But you cohtther hereding now I can't are
#
# You takes really was my hearty do you're My trickelm, my face
#
# , There
# Ske lake me fr
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 800000 iterations
#
#   we along standing
# At long it's lion and veound somebody ol leave chorus
# The roll your puas over, it work and gorned in souman, your close us nice of night,
#
# Theee
#
# , I known the blor.
# But're havy like a hoamises?
# Stils right all out, it will no siovet
# On a when in the christma yearn to oh.
# And then it go
#
# [Chorus]
# It's loving her along you in your ly
# There walkin' sometold like you sea
# There piod out of the Raince in your apsil the holf is you we rich you' call I'll wa
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 850000 iterations
#
#  Abost away...
# You broke a miss to rab in thry I hady
#
# , I didn't see the hand
# For Kivenths.
# I wanted to buaming
#
# And I look'?
# AN my ey, things another..........
# Hear bad tland of my heart.
# Grafy, you
# You can have aombroted for musmy on my back on the encs the haid I wanters, I arts I wantif times I drive
#
# , I nueve wasce love you bring to feelow
# Now you has that I'm in holound my heart's a tran on traic, the Hook my hand.
#
# And every ant nex of I masher time.
#
# You bett
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 900000 iterations
#
#  ur, you've got teaks be her forever.
#
# Thee
# Kin it's got well I needs
# Hone me, just the one I wnot notting of make me I will get hear
# Been on tray
# And I'm not laps
# A love
# And I'm good hood failise
# Just cod my look in to the grop here the swees
# So sessire of gons on lovingis one to you.
# I'm to keep...
# Baby shinent on
# Keep theather, love you.!
# Know lose in the seets
# Look on tryour not keemb.
# Happin' on touns.
# Someone on.
# One lying touch me)
#
# Forever
# No one
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 950000 iterations
#
#  an't ghowh
# Let it bell it
# The refles
# Don't ever terstlous tose livin' oh oh oh, insideds recserybed too uleg
# Sex, let me down feal in do bedy can't she,
# Best sexull kiss nice of're seem inside leartV
# Sex dasce (dis'
# Say this the wor'd weas anyterner, now I guested nothing you give that feel you never know I backil that yanother
# So look fellin' unfur the just not if you want too kunze, it like never net zy nexsta,
# And I not),
# I'm the comin' him)
# Don't reveored to there.
# I
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1000000 iterations
#
#   trick things
# Don't igg
# 'Cause you don't want 's
# Ccake
# Love, gonnie I'm needs
# My scrong, shall
# Don't yours it right tock
# Don't grade
# I want to me hear they rining ask me is over with the time in thould or love sand
# Baby,
# Yight
# My moving
# Yes, it in your eyes on the now
# Take you do is the stroin
# Don't need to be spit
# You don't was rold in the everyt with your eyes war keep go tongotiin' thinkin' loving I don't night
# 'Cause the moon)
# In eves never still keep whiled
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1050000 iterations
#
#  ere'enatting, you pare you just is everyt seems and know
# Threepdading you
# That living
# Your came
# That's you
#
# Whit
# That se
# My heads change bleep
# That work, comes in the draus)
# Swiche
# Steason her back with Smelpy, niggas of even out a girl raitions so who, problecaspopy catch
# Cause my money down, livin' to get not of your phoving
# Net
# What's botting
# Than you walk, coming while
# Zo here and fael, nothin' of my girl my materny silving, uiking come in thoons and he
#
# [
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1100000 iterations
#
#  ey out
# Hey, so your secpos band boyt
# To limmeion.
# What hey, stroughin' hey, one's in Heye his eyffere's fun fucte intucoot
# I want to don't yeah
# Cause heye song
# Cummatels
# Maby strong of five forny denory should were fooling
# Stooring buy
# I'ckin', you knoud.
# Shortion again
# Coils a strip, hey, wimm
# Care of so pereims the lefoath out
# You're a faihty
# You've been stoom
# That day
# The drown hamble and I won't sey, he's over
#
# Chooney apit blow so scree
# It never doo pre
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1150000 iterations
#
#  and gonna are your lonely your eyes your heart of you's be
# I give me be the changedy where your trund she so momenthing outs
# From my wos the shallide fored on this, fored or, where shade, hashed gone in your every life)
# The time
# Gaverds you of you're bore of knews like is makes to tell yoursed
# You say bed
# Yourds from me
# In this over me
#
# You cath me
# You gong cames
# You're of trob for me
# So so lifery-Swild
# Before
# I could always are is out is on
# Cor me
# Who walk that y
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1200000 iterations
#
#
# I knew
# Feet and it lordd, weepperp to met enes: x2]
# Get it we hold at hornty faip
# I've see srut in me
# I love
#
# Nothing
#
# , I am life
# It dreams my ose i
# lors to my love, never leave hock head love nowhirssed to going out burdersy of die
# Foolly I'm roll over lefore
# Don't for that ent, 'low my hims to my won't love from red in there
# I can
# Shiaimy herse to ratuy
#
# You dear
# Yerh
#
# I say
# Something
#
# Now
#
# [Chorfuling through there
#
# I look beliail chemiaal aw
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1250000 iterations
#
#  you
# You hate.
# so Cupion
#
# You pass on you ep me phone
#
# , (Race Lime I'm alrepty
#
# When you'd
#
# Nags for a doo make she neal, I just way underthone to burtctes in things me face
# Understoys toot king down
# 'Cause one ringing
#  yeahh)
# What I'd stay on to the mound, Cheike changen
#
# Oh you ever can't Never ricks on me
# And I just bed
# "
#
# Here gont by you wone
# And I be heart when I I just ratonege
#
# There's not. What's your wannte notiles phayep
#
# No todoohbee
#
#
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1300000 iterations
#
#  s We case he was tree travery
# The Frow
# Come in there
# No lidden't prace Drid, aspey from ott brigd a marts cheem regromet on there
# You're love awayld to you
# Tell the sweep troketic pars Namerd in fis found song the moue off in the beand
# Come of, stop Fiorgay, down blugh the morning
# The one
# That we see
# Shaping Bars the fid to housoons
# Your from sore wives in the love
#
# , Alasare's all in the finced to Christmas it bum Day is Chrissing will Spends see was a way
# You're breathers
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1350000 iterations
#
#  ke it
# Find Jumblinating Down Dew again!
#
# Don't happen Down Mornty Down
# Down Dear
# Down Roscan do God dog Loess
# Doon that I make New nothin' me knee The Girls:) For
# No cup That's beonin Teep Un Chorus:] Live Touck Un ENebly
# Like me Discre
# (Things
# Down
#
# Coming it
# On Itrapy feel Loother Bridght Too
# Deat of Come Gonnic I don't Did If Lord me
# It I will be Ning
#
# Tetling Tou
# With you make up Now
# The stant hold Down
# Just BOgis
#
# Who's Gire
# Then
# I saaking me
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1400000 iterations
#
#
# We'll I wonder
#
# (Cill think you anythince
# Well by
# Baby!
# Whi'll.
# And you you'll think you woutr that you want to be dory from they think it's ter soulb!
# True me
# We're love is go or good the side
# Walkin' remembed pround.
# 'crudly it
# 'cause high to yos chull at peoph whell dreamed your ard
# You
# I don't can she's gonna try to help you"
# And you want you down it's some guy?
# Found that it's a things if you should sure
# We've got try who hive
# Who me face
# Sood the ccapp
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1450000 iterations
#
#  es, life will agot a sporman, like my book hast
# It I woshingle irea
# By of this house
# I've brebotise back, I just cauring my hardods
# Who cry shide
# Todida's great they juder
# I could never codry put I don't mine
# To chan stere
# Tear me faving all viswered
# Oh, I's couth where just cry
# Thought, that why where again and end
# That should be
# I chronit
# That you were comp this best of it wish
# That we are todio" that I can make I could never I'd know
# Where eppage my gund brinmes
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1500000 iterations
#
#  drost you, la up call y'alking up I'm be cruck hurts like talke was right spent it fly up raior's but thecet
# Speme
# But a listakonomaks, same closer She young no
#
# Calling agaich girl
# (Wit losh
# I'm all sky the nigga
# Draingga keep of your gandroal
# I ppain
#  fall an my luckin' 9-belfe my pop fore niggat things flulld
# You damgelf wify you last spand iilues
#
# La lagmy
# I nices
#
# How.
# Have ple causer you can a.Budne you can fucking just a truged up bunot us 'ro.lh new clows
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1550000 iterations
#
#  y I all wouldn't wrach carelt, you're is all anoth one only yantch a puremm meets to
# All the wame we wam a blow up my life
# I do you was al
# Like this paper wate my facion is go
# Slown a liven of suce man down you haven't love
# And if I losp, this waste
# All my real me, have that's can life's doubt we gaid, I do in they lingring and thrteps
# And I lakele me
# We meon
# We make a was nights ichertall way
# You wastin' as like thought
# All a have me
# And I stoper
# And I just stild was t
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1600000 iterations
#
#  night to lookingle fly, you can't take a magin' here
#   One hanga and he come, homble end, this not wandin' is gone
#
# Blame if you pray don't standy, Motter leave a hard Semplanthed you
#
#
# Will gets and you gottaras Fron, Fortht and that is that I heavy go deep)
# Gonna haven't he deatelw,
#
#
# Day this let that day and want gry-don't be leave you understand nothing Mim to did a go to way that we make, to that you long.
# Walking on corme down that dream.
# If you proungly a pathing that ke
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1650000 iterations
#
#  omeday of makin insse in thel
# The little nive a ly only fool lefe
# Stop go this mouns erosmered in med for it off
# And the found choombite and righfing to clear
# But my head I gonne home that you.
# If I won be usland, not spilly
# And my read lad on, a crosme
# Stap was another then I've been her friend-appelsin' on theart mind
# Row row by a buese's now if the bett, He'm her lieving meandy the methore will grouckle away and you've took a joker of
# The goie enough fee and it love and know
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1700000 iterations
#
#  a potes,
#
# Shirg!
#
# , In't losted
# Believe
# It said days knows fat: my show think fulls hopes the vick to the guid!
# It buels
# It's friend wike tolds
# Ei times falleshimes to slice
# Likesbond
# I like to the like, [Row we was gonna through,
# It the to falls we gate feels the cabehse I'm sent here are was stand. that folleed me
# All chanely outed shir sm funnessess,
# HOPlone
# The light
# Take
# Holf last beerdnaahowally why what you terselfind
# An was racked through the voicanest!
#
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1750000 iterations
#
#  , at, all, he never follinened all throw, said aings
# Now about plane, all out a clack
#
# And all ppore, hey any comes in honoh all, a little Why I I problet the hosven
# Oh the because all, het the past and plailine my heardoadain.
#
# Soon all, everything, couring in the mayth Or my all maybe all pleasion
# But if I could at not will like it for the closer
# And I see it's aritic
#
# Ohing of take time ablead in the priars, time slipped of de'll been about a like didn,
# I losh is couch a
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1800000 iterations
#
#  ponce at glounds enty pareded and from me
# I seeessland on
#
# Just clouke the street and played
# And bered times of hair to get to heees so 3reaple 'lieesed and he made to high there" you said
# He-wow it aheld we feels they and our
# Door else)
# Any plead
# They paszight in my smile
#
# Oh -ysterse "I don't sle can I stay I wo my eyes
# Dadged so my headon my folwers and he'llet, and survotiow The street come my flout words we had me
# ,Itreated
#
# Actradri-mate)
# I was so beesosting a
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1850000 iterations
#
#  t when wid' chase whow I'm no poping forgom, I wouth love losfeck, I should begict.
# Open to your act Moul to "I say,
# Your love who peaving to my life.
#
# Every name
# Oh when mortitue
#
# , [Choruho, rigitch that the lone out, I wouldng, then they thander, more when.
# Wit lord, get coremottry gove to, I have someone, I to thy sometimies, get ware
#
# Is the word.
# Oh heaven, mot
# So the e chet no to your bee Given you canywelide, changetter god love risen I need here cause I went will bet
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1900000 iterations
#
#  er can't to begracryt that's desidel
# The e bit oully you well wrist
# Noca you must me
# In me
# Just a head alones that Opa ht falling
# Yearser in yo- Dee midned a halled it out my hear
#
#
# Stoold man forguser aftoly come those lord
# I'm see
# In cate you
# If you must change
# And in?  nothion'lu is fiest is the nambes that I lear
# You g.
# One singling for you he, hears I can't songe
#
# , [Qombusely feel me me?
# I with the rence to the filpped and your lifnel you looking leave they end
#
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 1950000 iterations
#
#  will searchen that I'm a purty are care King to be all the some in loving, by no sky I tell still before as here in a dayly come of goodh me seems up "Now we ret everybld and devisust to your calling evrels tone, "Crading me stays as untold and he's the trubbed me you
# And spelda seed sacpons.
# She's trust and thingbory thring you're see, "Your stranch on
#
# If you sun it have to spenthar you beater up wo'm a song how in no a fleve at true, the stilling heaven, danger,, I know soben that I j
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2000000 iterations
#
#  ou ever pime
# Like just wrise you
# Withings repell
# Cause whist you bustife buinite
# And you want no feeling
#
# You are don't can't hurstine you
# Cause I see just you join no promise for you
# It take this hamber is it make in love telling
#
# Is my ocifore
#
#  it's enough
# It wanning of tided every faich
# I just guess
# To be baby want to though trugs of you
# And dreams would you nears
# But it's just you know the enouh
# And on with you cowchoor night
# Now the demmautions just mist
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2050000 iterations
#
#
# It was bial begind I was thingle it and pass
# If of what once for the heart?
# It gets on)
# Believe change are pasself Backless and I knee
# I'm lot me-be
# I'reaplen me for that I down it step high understais
# Till thewell ask tracks
# It's so I'm faincend a way at...
# I'm like yeah
# There not the sound!
# And placine
# And that's to have walk lets bath it and really so forrow' thinking tallleats it's a but it to be friisie
# It's been on magsan
# If you say It's look
# We afters
# It's
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2100000 iterations
#
#  be
# Back aghoth in try back hurthingin usare yeah
# Like
# Agostry in.
# Soll
# Trave, will be here you're ashands, here
# This little by the once boy, now, silioning and crites.
# I'm troked about you freenford lace.
#
# Look
#
# I see years, whend your heiving to the irlveding, little abuse and we have say
# For he had beat I try and the many now hand of iffreet will changerisning in last ourser to prift
# The endh
# 'Cause that bearmmy mearming?
# Theracks lived yours from your mind you're
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2150000 iterations
#
#  e his endis, like so Mass she was hin the younking need his woman
# tuine throw I got blied that let dure, be more where becailt pownintarin' overy's down down she graiserly whrid!
# Gonna keeps
# Steel up, and the sink fiem you will get it beausing of
# No flift away drigh
# She walk
# It saw
#
# She's girl,
# I sand.
#
# Oh no, halles, they'rietin, friends live a rown, child reguybogers
#
# Down
# Friend your nig eighs from, hang
#
# Befolow
#
#
# But she calling, My bright that's gone's
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2200000 iterations
#
#   fuss was cussion
# I days used in are grow
# Foovery loving for your arishB
#
# That we'll well, - She wave?
#
# Whisios weam dancuen to gave nee
# We go the should confased we have greed gust well.
# We sing)
# Well the walls
# We gonna found clomes of were!
#
# Alls.
# But the wouste
# Fell,
# Those ever have your pul your lwere it
# And all.
# Well wene your
# Playith and we fast aid away! Word
# We wish shourd!
#
# Older won'isit to for consuler, you have hand.
#
# Crying
#
# Ain't to
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2250000 iterations
#
#  g on uptical
# Once once entere dumply memino
# Oncol, down, a try.
#
# , (Pasuntion, wate upons looks
# I'm lost, what all starting a.O
# Someteling?
# I'd looks are risidaty
# I do fillas for dickiny down of farsing
# Cor insion
# Come?
# I just fakints for the gotef for use who know the here's pheat the sat they you
# Stop facking
# I'm joy sup windon show the males you how adus
# And yeah
# And has mask will happy and awain
# I'm ferred
# I'm reading could take a heance from doup to my answay
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2300000 iterations
#
#   baby baturr'ed on and I hearding eyes threadsa
# And nothing to ringion fooldin' to get your blue-after we cauld they can't get fulliping of eChey
# I get to fall with our time baby, corted out
# We can,
# And he wighed for my head gold up
# I've wondy get tell your knother just got night opin' backeds in always that I broked every gimell give how scaus we turningy crit of my consed
#
# Hope corth seccemes well I've face
# And nothing longs meantbomy naving love out, the Love you won't baby
#
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2350000 iterations
#
#
# This the belling
# All the trut girl
# The land behe, ball,
#
# To the bus gullow, intons, down.
# And love thing I need and the bing
# Tell us she her my light my bigba,
#
# The shise!
# The old to the back
# Take blacks shine, nigging but back a morn bratling, love
# Round
#
# , To knowing,
#
# The sm swin, loven us drecks going a much oh morning
# The by hos burniel
# The red, bright
# The swine
# Reonaut gate baby
#
# Oo, buntcorther wait be girl enen one by the back back.
# But I'm le n
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2400000 iterations
#
#   down there's a moving me
# May nicking
# I have throuch and and sunside a girl
#
# And it see my abrumect ritirat heras me
# There's Love a darling up they coaching
# And we mak all mon
# Sad want is list it wother the sand of the puhs thour the pose I want morisia
# It's happy destrainS a betum the pay it and Gam a grel mys and your funs around
#
# To got a who never guily the Charger veach
# Whese I wants
# A say I'm nater...
#
# Hear by heave
# Gameh a wos keep
# A love that I'm all a des
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2450000 iterations
#
#  ieder aomy is why cried)), I I lost try to you,
#
# Every nizze rocke, no until back your night and shesse umo'd in we wants knot so one where's the baby
#
# We cannt, no ebee)
# She's down
# Eac out means, what you've yeah, watchance Conced, drees so she toous, even ties, it's I heaveny lust my broks you
#
# In and on time, I make my lingers you want, I do I heive about you row, now the roworr my
# Coot, she can't when I can my time, I know no
#
# She's down, it's my nigg every wheah your h
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2500000 iterations
#
#   it again
# And musmess about moer
# There's blume too don't will you not satisters class but he just get for you arove
#
# Don't see the ckee to the girma
# Hereate
# You didn't might no Slie it's plade 'la playle be in frounb talk then Remem
# Standing and it's sleeplane your come of your she was a with it beed to glack home us gonna liase 'Bud to go
# If the statway to stand again away
# You know it's trust treal of him told, in a wimn pard
# Kart in the baby
# , I give my sound again tautle
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2550000 iterations
#
#  at the bettila play blue
#
# [Gomanary matters bring I mighter that so them helt
# You could always black that I had Crost.
# You remound the way the halle of Be under back that and I'm no they losen won't crysafted and see
# For chancessing lie now without turne nothing
# Depertable
# And
# Or saviling live days Frove
# But I'll think are a dreams and looking alringard of my letter
# I'm sccouth burne go the mind In than I'm gone
# I lears the one hand
# A said man when the-rapperiod comess yo
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2600000 iterations
#
#  t
# Burn with praying the Bialger rives of Scrawing in the up
# Reaf walk
# Set
# I lie
# I bug-
# The e left you evil
# Ride the Screed I we giMp we yore don't want me power with ore
# Conigh com the evertLore
# And we cowfod
#
# Feel in the versedcicned one one We there words and Coll intonn thise
# Goond there es a Maked the wommour lied of
# [Chorus] Strite
# The twice of palling DAREVNFYourn of park
# Yourser
# Nothish no one Last is highth
# COMARAY him of Frore
# Feelss anstine this wins
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2650000 iterations
#
#  be unsiles gets with the twith
# We're boy, weather, he's go buift, he's look her to get a was togething for pro wey love down, I guinne a placener,
# We haves wishe'ver arable crats a Bain into stone, mence, seeps)
#
# [Chorus]
#
# He want a assets a lond
# Anop were here I'll probled)
#
# [Chorus].
# Awah
#
# Baby
# And are feme in this her, you was in, I know the excuntions breather was no piay fisping as there's cars linging)
# Catmmose eduly
#
# Not leave up
#
# I come of people coll
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2700000 iterations
#
#  t god andge ass the by what I'm
# I say
#
# Noch got a batmaue]
# Witledsmojoh,
# I borower there yeah)
# And the s thrugh agos the hamety lookin' to me
# Up, she from the manited damn , surent let me about the waitired, ass reit the measy
# Puph the sorn, ooh)
# (Het and and strong trus and she know breck that when yeah) stop me my ride
# I are tir a hear!.
#
# So balling is want the clanding eyvt don't run
# Till pleares at me.
# We bam out meard Jeathen
# What game up wrong locker.s up you ggre
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2750000 iterations
#
#  those a prizes see?
# That seven
# Line
# When was here of aske-weal the niness my pund all, to you Jung ad by the time I ain't be alryms
# Oh Cood all away for the really faif to be waitlise
# The cold in tart and take your boy
# I madming now Shey mornie inded to stept your game we tade
# I cool I see hurad
# Who year befor) back the lite
# I let me keepse couldn't be free my love my sound you need my Fazy another
#
# We hell
#
# And I see your since comes
# Pearn !
# Tell the grad
# I ciorn
#
# -------------------------------------------------------------------------------------------------------------------
#
#
#  After 2800000 iterations
#
#  akes
# You know I'll big restallifut nothing
# Do)
#
# , Tetch at feelin' up upon it each maick
# Let me
# Leps
# All up here line, Lorders to come a mott isend
# My night
# That holl it's give it nelve hands a-c one up too maves
# To say
# But a lisferd hood
# But one viste, at how emotets quitpion!
# Thet's elves, here
# And
# Why
# She kn-wo invachin'
# Male
# And it's all it say, elvin'
# Elv
# Haod it right
# That I'm
# Nothing)
# And I'm Go, start etenem, I had aresse!
# He's a veate are woon
#
# -------------------------------------------------------------------------------------------------------------------
